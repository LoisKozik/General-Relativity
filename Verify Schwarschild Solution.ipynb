# %%
from General_Relativity import *

# %% [markdown]
# # Schwarzschild Metric
#
# The goal of this notebook is to verify that the Schwarzschild metric is a solution to the Einstein equation. The Schwarzschil metric can be written in the Schwarzschild coordinates ($ct$, $r$, $\theta$, $\phi$) :
#
# $$\mathrm {d} s^{2}=-\,c^{2}\mathrm {d} \tau ^{2}=-\left(1-{\frac {2GM}{c^{2}r}}\right)c^{2}\mathrm {d} t^{2}+{\frac {\mathrm {d} r^{2}}{1-{\frac {2GM}{c^{2}r}}}}+r^{2}\left(\mathrm {d} \theta ^{2}+\sin ^{2}\theta \,\mathrm {d} \varphi ^{2}\right)$$
#
# The Einstein fiel Equation is :
#
# $${\displaystyle R_{\mu \nu }\ -\ {\frac {1}{2}}\,g_{\mu \nu }\,R  = \frac{8\pi G}{c^4} T_{\mu \nu }}$$
#
# But in the vacuum, the stress-energy tensor is zero ($T^{\mu \nu} = 0$), so the Einstein field equation simplifies to :
#
# $${\displaystyle R_{\mu \nu }\ -\ {\frac {1}{2}}\,g_{\mu \nu }\,R  = 0}$$

# %% [markdown]
# ### Schwarzschild Metric

# %%
S
# Out:
# Matrix([
# [2*G*M/r - 1,                0,    0,              0],
# [          0, 1/(-2*G*M/r + 1),    0,              0],
# [          0,                0, r**2,              0],
# [          0,                0,    0, r**2*sin(θ)**2]])

# %% [markdown]
# ### Christoffel Symbols

# %%
Display_Christoffel_Symbols(FLRW)
# Out:
# ${\Gamma}_{r,r}^{t} = - \frac{a{\left(t \right)} \frac{d}{d t} a{\left(t \right)}}{c^{2} \left(k r^{2} - 1\right)}$
# ${\Gamma}_{θ,θ}^{t} = \frac{r^{2} a{\left(t \right)} \frac{d}{d t} a{\left(t \right)}}{c^{2}}$
# ${\Gamma}_{Φ,Φ}^{t} = \frac{r^{2} a{\left(t \right)} \sin^{2}{\left(θ \right)} \frac{d}{d t} a{\left(t \right)}}{c^{2}}$
# ${\Gamma}_{t,r}^{r} = \frac{\frac{d}{d t} a{\left(t \right)}}{a{\left(t \right)}}$
# ${\Gamma}_{r,t}^{r} = \frac{\frac{d}{d t} a{\left(t \right)}}{a{\left(t \right)}}$
# ${\Gamma}_{r,r}^{r} = - \frac{k r}{k r^{2} - 1}$
# ${\Gamma}_{θ,θ}^{r} = k r^{3} - r$
# ${\Gamma}_{Φ,Φ}^{r} = r \left(k r^{2} - 1\right) \sin^{2}{\left(θ \right)}$
# ${\Gamma}_{t,θ}^{θ} = \frac{\frac{d}{d t} a{\left(t \right)}}{a{\left(t \right)}}$
# ${\Gamma}_{r,θ}^{θ} = \frac{1}{r}$
# ${\Gamma}_{θ,t}^{θ} = \frac{\frac{d}{d t} a{\left(t \right)}}{a{\left(t \right)}}$
# ${\Gamma}_{θ,r}^{θ} = \frac{1}{r}$
# ${\Gamma}_{Φ,Φ}^{θ} = - \frac{\sin{\left(2 θ \right)}}{2}$
# ...

# %% [markdown]
# ### Riemann Tensor

# %%
Display_Riemann(S)
# Out:
# ${R}_{r,t,r}^{t} = \frac{2 G M}{r^{2} \left(- 2 G M + r\right)}$
# ${R}_{r,r,t}^{t} = \frac{2 G M}{r^{2} \left(2 G M - r\right)}$
# ${R}_{θ,t,θ}^{t} = - \frac{G M}{r}$
# ${R}_{θ,θ,t}^{t} = \frac{G M}{r}$
# ${R}_{Φ,t,Φ}^{t} = - \frac{G M \sin^{2}{\left(θ \right)}}{r}$
# ${R}_{Φ,Φ,t}^{t} = \frac{G M \sin^{2}{\left(θ \right)}}{r}$
# ${R}_{t,t,r}^{r} = \frac{2 G M \left(- 2 G M + r\right)}{r^{4}}$
# ${R}_{t,r,t}^{r} = \frac{2 G M \left(2 G M - r\right)}{r^{4}}$
# ${R}_{θ,r,θ}^{r} = - \frac{G M}{r}$
# ${R}_{θ,θ,r}^{r} = \frac{G M}{r}$
# ${R}_{Φ,r,Φ}^{r} = - \frac{G M \sin^{2}{\left(θ \right)}}{r}$
# ${R}_{Φ,Φ,r}^{r} = \frac{G M \sin^{2}{\left(θ \right)}}{r}$
# ${R}_{t,t,θ}^{θ} = \frac{G M \left(2 G M - r\right)}{r^{4}}$
# ${R}_{t,θ,t}^{θ} = \frac{G M \left(- 2 G M + r\right)}{r^{4}}$
# ${R}_{r,r,θ}^{θ} = \frac{G M}{r^{2} \left(- 2 G M + r\right)}$
# ${R}_{r,θ,r}^{θ} = \frac{G M}{r^{2} \left(2 G M - r\right)}$
# ${R}_{Φ,θ,Φ}^{θ} = \frac{2 G M \sin^{2}{\left(θ \right)}}{r}$
# ...

# %% [markdown]
# ### Ricci Tensor

# %%
R_tensor = All_Ricci(S)
Display_Ricci(S)
# If the Display_Ricci function returns nothing, it means that the components of the tensor are all zero

# %% [markdown]
# ### Ricci Scalar

# %%
R = Ricci_Scalar(S)
Display_Ricci_Scalar(S)
# Out:
# $R = 0$

# %% [markdown]
# Hence the Ricci tensor and the Ricci scalar are all zero, so the Einstein fiel equation is satisfied.
